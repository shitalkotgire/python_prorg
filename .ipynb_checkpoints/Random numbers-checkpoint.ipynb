# %%
#genrating random numbers
import random
#random module generates a float number between 0 and 1.
x=random.random()
print(x)
# Out:
# 0.719508295368833

# %%
#The randint() method generates a integer between a given range of numbers.
x=random.randint(5,10)
print(x)
# Out:
# 7

# %%
#The randint() method generates a integer between a given range of numbers.
x=random.randint(5,10)
print(x)
# Out:
# 10

# %%
#Generating a List of numbers Using For Loop
randomlist = []
for i in range(0,5):
    n = random.randint(1,30)
    randomlist.append(n)
print(randomlist)
# Out:
# [2, 13, 16, 2, 8]

# %%
#Generating a List of numbers Using For Loop
randomlist = []
for i in range(0,5):
    n = random.randint(1,30)
    randomlist.append(n)
print(randomlist)
# Out:
# [11, 22, 29, 16, 5]

# %%
#Using random.sample()
#Generate 5 random numbers between 10 and 30
randomlist = random.sample(range(10, 30), 5)
print(randomlist)
# Out:
# [26, 25, 21, 29, 16]

# %%
#Generate 5 random numbers between 10 and 30
randomlist = random.sample(range(10, 30), 5)
print(randomlist)
# Out:
# [14, 15, 25, 18, 11]

# %%
#1. choice() :-  returns a random item from a list, tuple, or string.
# prints a random value from the list
list1 = [1, 2, 3, 4, 5, 6]
print(random.choice(list1))
 
# prints a random item from the string
string = "striver"
print(random.choice(string))
# Out:
# 1
# r

# %%
#2. randrange(beg, end, step):- generate random numbers from a specified range and also allowing rooms for steps to be included.
print(random.randrange(20, 50, 3))
# choose from 20 23 26 29 32 35 38 41 44 47 49
# Out:
# 38

# %%
""" seed():- it is used to save the state of a random function so that it can generate some random numbers 
on multiple executions of the code on the same machine or on different machines (for a specific seed value).
The seed value is the previous value number generated by the generator. For the first time when there is no previous value,
it uses current system time.
"""
# using seed() to seed a random number
random.seed(5)
 
print("The mapped random number with 5 is : ", end="")
print(random.random())
 
# using seed() to seed different random number
random.seed(7)
 
print("The mapped random number with 7 is : ", end="")
print(random.random()) 
    
# using seed() to seed to 5 again
random.seed(5)
 
# printing mapped random number
print("The mapped random number with 5 is : ", end="")
print(random.random())
 
# using seed() to seed to 7 again
random.seed(7)
 
# printing mapped random number
print("The mapped random number with 7 is : ", end="")
print(random.random())
# Out:
# The mapped random number with 5 is : 0.6229016948897019
# The mapped random number with 7 is : 0.32383276483316237
# The mapped random number with 5 is : 0.6229016948897019
# The mapped random number with 7 is : 0.32383276483316237

# %%
#shuffle():- It is used to shuffle a sequence (list). Shuffling means changing the position of the elements of the sequence. 

sample_list = ['A', 'B', 'C', 'D', 'E']
 
print("Original list : ",sample_list)
 
# first shuffle
random.shuffle(sample_list)
print("\nAfter the first shuffle :",sample_list)
 
# second shuffle
random.shuffle(sample_list)
print("\nAfter the second shuffle :",sample_list)
# Out:
# Original list :  ['A', 'B', 'C', 'D', 'E']
#
# After the first shuffle :  ['E', 'A', 'C', 'D', 'B']
#
# After the second shuffle :  ['C', 'D', 'A', 'B', 'E']

# %%
#6. uniform(a, b):- This function is used to generate a floating point random number between the numbers mentioned 
#in its arguments. It takes two arguments, lower limit(included in generation) and upper limit(not included in generation).

print(random.uniform(5, 10))
# Out:
# 9.54852031571551
